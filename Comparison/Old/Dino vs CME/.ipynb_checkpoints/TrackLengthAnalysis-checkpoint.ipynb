# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

# %%
Comparison = pd.read_csv("Output Data/Comparison.csv")

# %%
#ids_to_remove = Comparison.loc[Comparison["Distance"] >= 3.5, "ID (Dino)"].unique()
#Comparison = Comparison[~Comparison["ID (Dino)"].isin(ids_to_remove)]
#Comparison = Comparison[Comparison["Distance"] < 3.5]

# %%
#a = Comparison[Comparison["Track Length (CME)"]==Comparison["Track Length (Dino)"] and Comparison["ID (CME)"]]
d = Comparison["ID (Dino)"].unique()

# %%
M_comp = Comparison.to_numpy()
ID_vec = defaultdict(list)

for ID in M_comp:
    ID_vec[ID[0]].append(ID)

for ID_val in ID_vec:
    ID_vec[ID_val] = np.array(ID_vec[ID_val]) 

ID_list = np.zeros((len(ID_vec),5), dtype=object)

# %%
for i, ID in enumerate(ID_vec):
    ID_val = ID_vec[ID]
    CME_ID = np.unique(ID_val[:,0])
    Dino_IDs = np.unique(ID_val[:,1])
    TL_CME = np.unique(ID_val[:,13])
    TL_Dino = np.unique(ID_val[:,14])

    ID_list[i][0] = CME_ID
    ID_list[i][1] = Dino_IDs
    ID_list[i][2] = TL_CME
    ID_list[i][3] = TL_Dino
    
    #if len(Dino_IDs) == 1 and TL_CME == TL_Dino:
    if np.all(ID_val[:,15]) < 3.5:
        ID_list[i][4] = True
    else:
        ID_list[i][4] = False

# %%
Sum = pd.DataFrame(ID_list, columns = ["ID (Dino)","ID (CME)", "Track Length (Dino)", "Track Length (CME)", "True Match"])
Sum.to_csv("Output Data/Sum.csv")

# %%
track_lengths = np.array([row[2][0] for row in ID_list])
mask_true = np.array([row[4] for row in ID_list])
print(mask_true)
bins = np.arange(0, 110, 10)

counts, _ = np.histogram(track_lengths, bins)

counts_true, _ = np.histogram(track_lengths[mask_true], bins)

print(counts)
print(counts_true)

labels = np.array(("0-9","10-19","20-29","30-39","40-49","50-59","60-69","70-79","80-89","90-99"))
display(Comparison[Comparison["Distance"]>3.5])
# Out:
# [False False False ... False False False]
# [33479  2668   814   355   165   101    58    27    26    30]
# [2740  582  248  113   62   45   23   11   13   19]
#         ID (Dino)  ID (CME)   x (Dino)   y (Dino)    z (Dino)  x (CME)  \
# 0             0.0     954.0  497.79352  342.82275   93.872870   462.11
# 1             0.0     954.0  497.46310  343.23276   94.276695   462.45
# 2             0.0     954.0  496.60742  340.29070   93.843010   462.44
# 3             0.0     954.0  498.56644  338.08292   94.058914   462.57
# 4             0.0     954.0  498.38843  339.43130   94.050766   462.41
# ...           ...       ...        ...        ...         ...      ...
# 178317    37718.0     662.0  530.96747  643.22390  164.279420   534.91
# 178318    37719.0     662.0  546.19480  645.99896  164.227360   534.91
# 178319    37720.0     513.0  587.74896  379.07452  163.997340   602.93
# 178320    37721.0    1057.0  797.61584   89.70476  166.999710   722.16
# 178321    37722.0    1057.0  797.99700  140.65265  166.999370   722.16
#
#         y (CME)  z (CME)     t  t_start (Dino)  t_start (CME)   FI (Dino)  \
# 0       341.500   78.483   1.0             1.0            1.0   39.928734
# 1       341.810   78.972   3.0             1.0            1.0  156.430560
# 2       342.010   79.909   4.0             1.0            1.0  154.369000
# 3       341.310   80.556   6.0             1.0            1.0  148.742700
# 4       341.110   80.735   7.0             1.0            1.0  148.052810
# ...         ...      ...   ...             ...            ...         ...
# 178317  647.230  146.542  99.0            99.0           70.0  178.849990
# 178318  647.230  146.542  99.0            99.0           70.0  201.268940
# 178319  375.730  147.937  99.0            99.0           65.0  164.344000
# 178320   68.956  139.031  99.0            99.0           78.0  155.851030
# 178321   68.956  139.031  99.0            99.0           78.0  171.760560
#
#         FI (CME)  Track Length (Dino)  Track Length (CME)    Distance  \
# 0        176.560                  5.0                23.0   38.883304
# 1        195.410                  5.0                23.0   38.238398
# 2        190.930                  5.0                23.0   36.939480
# 3        189.700                  5.0                23.0   38.580908
# 4        210.040                  5.0                23.0   38.400196
# ...          ...                  ...                 ...         ...
# 178317   212.900                  1.0                30.0   18.606678
# 178318   212.900                  1.0                30.0   21.015093
# 178319    99.087                  1.0                35.0   22.351383
# 178320    41.358                  1.0                22.0   83.104414
# 178321    41.358                  1.0                22.0  108.045777
#
#        Multi ID (CME) Multi Distance (CME)
# 0                 NaN                  NaN
# 1                 NaN                  NaN
# 2                 NaN                  NaN
# 3                 NaN                  NaN
# 4                 NaN                  NaN
# ...               ...                  ...
# 178317            NaN                  NaN
# 178318            NaN                  NaN
# 178319            NaN                  NaN
# 178320            NaN                  NaN
# 178321            NaN                  NaN
#
# [132614 rows x 18 columns]

# %%
plt.bar(labels,100*counts_true/counts)
plt.xlabel("Track Length")
plt.ylabel("Dino vs CME Match (%)")
plt.show()

# %%
selected = ID_list[ID_list[:, 4] == False]
breaks = np.array([len(x) for x in selected[:,1]])-1
plt.scatter(selected[:,2],breaks, s = 0.5)
plt.show()

# How define break?
