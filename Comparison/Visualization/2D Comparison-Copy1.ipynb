# %%
import os
import tifffile
import stackview
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from skimage import exposure

# %%
time = 99

# %%
root_dir = "/nfs/scratch2/shared_image_recog_ml/ap2_unnorm"
folders = [
    f for f in os.listdir(root_dir)
    if os.path.isdir(os.path.join(root_dir, f))
    and not f.startswith(".")
]
folders.sort()

selected_folder = folders[time-1]

volume_path = os.path.join(root_dir, selected_folder, "volume.tif")
volume = tifffile.imread(volume_path)

# %%
CME = pd.read_csv("detections_CME.csv", header = None)
CME = CME[CME[0]==99]
Dino = pd.read_csv("counts_patch.csv")
max_projection = np.max(volume, axis=0)

plt.figure(figsize=(10,10))
plt.imshow(max_projection, cmap="grey",vmin=0, vmax=0.5)

plt.scatter(CME[2],CME[3], s = 2, color = "blue")
plt.scatter(Dino["x"],Dino["y"], s = 2, color = "red")

plt.axis("off")
plt.show()

# %%
CME = pd.read_csv("detections_CME.csv", header = None)
CME = CME[CME[0]==99]
Dino = pd.read_csv("counts_attn.csv")
max_projection = np.max(volume, axis=0)

plt.figure(figsize=(10,10))
plt.imshow(max_projection, cmap="grey",vmin=0, vmax=0.5)

plt.scatter(CME[2],CME[3], s = 2, color = "blue")
plt.scatter(Dino["x"],Dino["y"], s = 2, color = "red")

plt.axis("off")
plt.show()

# %%
CME = pd.read_csv("detections_CME.csv", header = None)
CME = CME[CME[0]==99]
Dino = pd.read_csv("counts_fused.csv")
max_projection = np.max(volume, axis=0)

plt.figure(figsize=(10,10))
plt.imshow(max_projection, cmap="grey",vmin=0, vmax=0.2)

plt.scatter(CME[2],CME[3], s = 2, color = "blue")
plt.scatter(Dino["x"],Dino["y"], s = 2, color = "red")

plt.axis("off")
plt.show()

# %%
def plot(ax, time, ID, boxsize):
    ID1 = SNR_CME_non[SNR_CME_non["ID (CME)"] == ID]

    selected_folder = folders[time - 1]
    volume_path = os.path.join(root_dir, selected_folder, "volume.tif")
    volume = tifffile.imread(volume_path)

    z_CME = ID1["z (CME)"].values[0]
    x_CME = ID1["x (CME)"].values[0]
    y_CME = ID1["y (CME)"].values[0]
    z_Dino = ID1["z (Dino)"].values[0]
    x_Dino = ID1["x (Dino)"].values[0]
    y_Dino = ID1["y (Dino)"].values[0]
    FI_CME = round(ID1["FI (CME)"].values[0], 2)
    Distance = round(ID1["Distance"].values[0], 2)

    H, W = volume.shape[1:3]
    y1 = max(0, int(round(y_CME - boxsize / 2)))
    y2 = min(H, y1 + boxsize)
    x1 = max(0, int(round(x_CME - boxsize / 2)))
    x2 = min(W, x1 + boxsize)

    frame = volume[int(round(z_CME)), y1:y2, x1:x2]
    patch_ymin = y1
    patch_xmin = x1
    patch_ymax = patch_ymin + frame.shape[0]
    patch_xmax = patch_xmin + frame.shape[1]

    ax.imshow(
        frame, cmap="gray", vmin=0, vmax=0.5,
        extent=[
            patch_xmin, patch_xmax,
            patch_ymax, patch_ymin
        ]
    )
    ax.scatter(x_CME, y_CME, color="blue", label="CME")
    if (patch_xmin <= x_Dino < patch_xmax) and (patch_ymin <= y_Dino < patch_ymax):
        ax.scatter(x_Dino, y_Dino, color="red", label="Dino")
    #ax.set_xlabel("x")
    #ax.set_ylabel("y")
    ax.legend(fontsize=8)
    ax.text(
        patch_xmin + 1, patch_ymin + 4,
        f"CME SNR = {FI_CME}\nDistance = {Distance}",
        fontsize=10,
        color="black",
        bbox=dict(boxstyle="round", fc="white", alpha=0.7)
    )
    ax.set_title(f"CME ID = {ID}")
    #ax.set_xticks([])
    #ax.set_yticks([])

# %%
time = 20
boxsize = 40

CME = Comp.copy()
CME["FI (CME)"] = CME["FI (CME)"] / 31
SNR_CME_time = CME[CME["t"] == time]
SNR_CME_non = SNR_CME_time[SNR_CME_time["Distance"] > 3.5]

possible_IDs = SNR_CME_non["ID (CME)"].unique()
random_IDs = np.random.choice(possible_IDs, size=12, replace=False)

n_rows, n_cols = 4, 3
fig, axs = plt.subplots(n_rows, n_cols, figsize=(12, 16))

for i, (ax, ID) in enumerate(zip(axs.flatten(), random_IDs)):
    plot(ax, time, ID, boxsize)

for ax in axs.flatten()[len(random_IDs):]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
#display(Comp[Comp["t"]==20])

# %%
dino = pd.read_csv("detections_Dino.csv")
dino["timepoint"] = dino["timepoint"]+1
dino = dino[dino["timepoint"]==20]
dino = dino[dino["x"]>260]
dino = dino[dino["x"]<263]

#dino

# %%
time = 20
boxsize = 40

CME = Comp.copy()
CME["FI (CME)"] = CME["FI (CME)"] / 31
SNR_CME_time = CME[CME["t"] == time]
SNR_CME_non = SNR_CME_time[SNR_CME_time["Distance"] > 3.5]
SNR_CME_non = SNR_CME_non.sort_values("FI (CME)", ascending = False)
display(SNR_CME_non)

choice = SNR_CME_non[SNR_CME_non["FI (CME)"]>4]

possible_IDs = choice["ID (CME)"][1:13]

n_rows, n_cols = 4, 3
fig, axs = plt.subplots(n_rows, n_cols, figsize=(12, 16))

for i, (ax, ID) in enumerate(zip(axs.flatten(), possible_IDs)):
    plot(ax, time, ID, boxsize)

for ax in axs.flatten()[len(random_IDs):]:
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
#            t  ID (CME)  x (CME)  y (CME)   z (CME)   FI (CME)  ID (Dino)  \
# 71002   20.0     718.0   387.91   460.92   87.4710  18.970323      649.0
# 17641   20.0     179.0   293.55   426.84   19.2650   8.961935      194.0
# 134461  20.0    1359.0   578.35   133.60  146.4400   8.081613     1224.0
# 47242   20.0     478.0   340.84   348.86   52.2110   7.273226      431.0
# 102979  20.0    1041.0   622.98   203.17  111.3500   7.121935      891.0
# ...      ...       ...      ...      ...       ...        ...        ...
# 82684   20.0     836.0   568.85   279.22   95.7450   0.761871      819.0
# 88327   20.0     893.0   580.90   267.93  101.2200   0.752194      819.0
# 120502  20.0    1218.0   508.00   520.77  134.9100   0.743032      863.0
# 6553    20.0      67.0   401.04   406.08    7.5238   0.711774       41.0
# 712     20.0       8.0   245.00   165.95    3.9726   0.660774       16.0
#
#          x (Dino)   y (Dino)    z (Dino)  FI (Dino)   Distance  \
# ...

# %%
def plot(ax, time, ID, boxsize):
    ID1 = SNR_CME_non[SNR_CME_non["ID (CME)"] == ID]

    selected_folder = folders[time - 1]
    volume_path = os.path.join(root_dir, selected_folder, "volume.tif")
    volume = tifffile.imread(volume_path)

    z_CME = ID1["z (CME)"].values[0]
    x_CME = ID1["x (CME)"].values[0]
    y_CME = ID1["y (CME)"].values[0]
    z_Dino = ID1["z (Dino)"].values[0]
    x_Dino = ID1["x (Dino)"].values[0]
    y_Dino = ID1["y (Dino)"].values[0]
    FI_CME = round(ID1["FI (CME)"].values[0], 2)
    Distance = round(ID1["Distance"].values[0], 2)

    H, W = volume.shape[1:3]
    y1 = max(0, int(round(y_CME - boxsize / 2)))
    y2 = min(H, y1 + boxsize)
    x1 = max(0, int(round(x_CME - boxsize / 2)))
    x2 = min(W, x1 + boxsize)

    frame = volume[int(round(z_CME)), y1:y2, x1:x2]
    patch_ymin = y1
    patch_xmin = x1
    patch_ymax = patch_ymin + frame.shape[0]
    patch_xmax = patch_xmin + frame.shape[1]

    z_tol=2

    mask_z = (CME_time[4] >= z_CME - z_tol) & (CME_time[4] <= z_CME + z_tol)
    close_points = CME_time[mask_z]
    patch_mask = (close_points[2] >= patch_xmin) & (close_points[2] < patch_xmax) & \
                 (close_points[3] >= patch_ymin) & (close_points[3] < patch_ymax)
    close_points = close_points[patch_mask]
    for idx, row in close_points.iterrows():
        ax.scatter(row[2], row[3], color="blue", label="CME Det" if idx == close_points.index[0] else "")
    
    mask_z = (dino_time["z"] >= z_CME - z_tol) & (dino_time["z"] <= z_CME + z_tol)
    close_points = dino_time[mask_z]
    patch_mask = (close_points["x"] >= patch_xmin) & (close_points["x"] < patch_xmax) & \
                 (close_points["y"] >= patch_ymin) & (close_points["y"] < patch_ymax)
    close_points = close_points[patch_mask]
    for idx, row in close_points.iterrows():
        ax.scatter(row["x"], row["y"], color="red", label="Dino Det" if idx == close_points.index[0] else "")

    ax.imshow(
        frame, cmap="gray", vmin=0, vmax=0.5,
        extent=[
            patch_xmin, patch_xmax,
            patch_ymax, patch_ymin
        ]
    )
    ax.scatter(x_CME, y_CME, color="darkblue", label="CME Base")
    if (patch_xmin <= x_Dino < patch_xmax) and (patch_ymin <= y_Dino < patch_ymax):
        ax.scatter(x_Dino, y_Dino, color="darkred", label="Dino Close")
    #ax.set_xlabel("x")
    #ax.set_ylabel("y")
    ax.legend(fontsize=8)
    ax.text(
        patch_xmin + 1, patch_ymin + 4,
        f"CME SNR = {FI_CME}\nDistance = {Distance}",
        fontsize=10,
        color="black",
        bbox=dict(boxstyle="round", fc="white", alpha=0.7)
    )
    ax.set_title(f"CME ID = {ID}")
    #ax.set_xticks([])
    #ax.set_yticks([])

CME = pd.read_csv("detections_CME.csv", header = None)
Dino = pd.read_csv("detections_Dino.csv")

# %%
time = 20
boxsize = 40

CME = Comp.copy()
CME = CME[CME[""]]
CME["FI (CME)"] = CME["FI (CME)"] / 31
SNR_CME_time = CME[CME["t"] == time]
SNR_CME_non = SNR_CME_time[SNR_CME_time["Distance"] > 3.5]
SNR_CME_non = SNR_CME_non.sort_values("FI (CME)", ascending = False)

dino_det = Dino = pd.read_csv("detections_Dino.csv")
dino_det["timepoint"] = dino_det["timepoint"] + 1
dino_time = dino_det[dino_det["timepoint"]==time]

CME_det = pd.read_csv("detections_CME.csv", header = None)
CME_time = CME_det[CME_det[0]==time]

CME_det_old = pd.read_csv("detections_CME_old.csv", header = None)
CME_time_old = CME_det_old[CME_det_old[0]==time]

choice = SNR_CME_non[SNR_CME_non["FI (CME)"]>4]

possible_IDs = choice["ID (CME)"][1:13]

n_rows, n_cols = 4, 3
fig, axs = plt.subplots(n_rows, n_cols, figsize=(12, 16))

for i, (ax, ID) in enumerate(zip(axs.flatten(), possible_IDs)):
    plot(ax, time, ID, boxsize)

for ax in axs.flatten()[len(random_IDs):]:
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniforge3/envs/tk/lib/python3.13/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ''
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 5
#       2 boxsize = 40
# ...

# %%
a = pd.read_csv("detections_CME.csv", header=None)

# %%
a[a[0]==1]
# Out:
#       0     1       2        3         4        5
# 0     1     1  268.92  332.290    3.7825   74.177
# 1     1     2  345.96  502.360    5.4485  129.010
# 2     1     3  381.83  352.820    4.1066  113.810
# 3     1     4  386.89  375.520    4.1879   49.730
# 4     1     5  269.17   18.510    3.8182  139.690
# ...  ..   ...     ...      ...       ...      ...
# 1532  1  1533  519.15  111.090  162.0400   64.579
# 1533  1  1534  529.39   74.268  163.5500   74.013
# 1534  1  1535  701.14   29.635  164.9100  114.140
# 1535  1  1536  504.42  678.570  164.0300  793.660
# 1536  1  1537  784.69  207.280  165.4800  193.800
#
# [1537 rows x 6 columns]
